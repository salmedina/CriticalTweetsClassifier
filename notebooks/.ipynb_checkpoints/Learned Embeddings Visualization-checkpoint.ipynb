# %%
import json
import umap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from easydict import EasyDict as edict

colors = ['#66b3ff', '#ff6666']
reducer = umap.UMAP()

# %% [markdown]
# # Load the data

# %%
data = json.load(open('../data/labeled_data.json'))
data_ids = []
with open('../src/adv_flood_3_val_idx.lst') as idx_file:
    data_ids = idx_file.readlines()
data_ids = [sample.strip() for sample in data_ids]
len(data_ids)
# Out:
# 437

# %% [markdown]
# ## Embedding space plotting function

# %%
def plot_embedding(umap_embeddings, labels, save_path):
    noncrit_embeddings = umap_embeddings[np.where(labels == 0)]
    crit_embeddings = umap_embeddings[np.where(labels == 1)]
    plt.scatter(noncrit_embeddings[:, 0], noncrit_embeddings[:, 1], c=colors[0], marker='o', label='non-critical', alpha=0.8)
    plt.scatter(crit_embeddings[:, 0], crit_embeddings[:, 1], c=colors[1], marker='^', label='critical', alpha=0.8)
    plt.legend()
    plt.gca().set_aspect('equal', 'datalim')
    plt.axis('off')
    plt.savefig(save_path)

# %% [markdown]
# # Baseline embeddings map

# %%
base_data = edict(np.load('../src/base_embeddings.npy', allow_pickle=True).item())
base_data.labels = np.array(base_data.labels)
base_data.embeddings.shape
# Out:
# (448, 200)

# %%
base_umap_embedding = reducer.fit_transform(base_data.embeddings)
plot_embedding(base_umap_embedding, base_data.labels, '../images/baseline_embeddings_map.pdf')

# %% [markdown]
# # Multitask embeddings map

# %%
mt_data = edict(np.load('../src/mt_embeddings.npy', allow_pickle=True).item())
mt_data.labels = np.array(mt_data.labels)
mt_data.embeddings.shape
# Out:
# (448, 200)

# %%
mt_umap_embedding = reducer.fit_transform(mt_data.embeddings)
plot_embedding(mt_umap_embedding, mt_data.labels, '../images/multitask_embeddings_map.pdf')

# %% [markdown]
# # Adversarial embeddings map

# %%
adv_data = edict(np.load('../src/adv_embeddings.npy', allow_pickle=True).item())
adv_data.labels = np.array(adv_data.labels)
adv_data.embeddings.shape
# Out:
# (448, 200)

# %%
adv_umap_embedding = reducer.fit_transform(adv_data.embeddings)
plot_embedding(adv_umap_embedding, adv_data.labels, '../images/adversarial_embeddings_map.pdf')

# %% [markdown]
# ## Adversarial umap embedding cluster analysis

# %%
left_cluster, right_cluster = list(), list()
for idx, e in enumerate(adv_umap_embedding):
    if e[0] < -1:
        left_cluster.append(idx)
    elif e[0] > 5:
        right_cluster.append(idx)

# %%
for idx in left_cluster:
    if idx <  len(data_ids):
        print(f'{data[data_ids[idx]]["label"]}: {data[data_ids[idx]]["text"]}')
# Out:
# low: rt fact genesis 8 712 is about no ahs ark today is 8 712
# low: rt people needing help may text at 0905 1456 217 | 092 935 100 68 | 093 2360 8 563 please re tweet
# low: mt de la salle college of saint benilde following the official announcement to suspend
# low: the u.s. embassy here in manila looks like it is floating above the flood it has been two weeks and the hea
# high: trapped no food water since 9am ellen p h9 mariposa st midtown village cainta 090 624 24 937
# low: stay tuned for announcements check the
# low: this is the moment i really love which had a great heart for filipinos | she is a total package of modern woman
# low: photos floods in manila are displacing tens of thousands of people |
# low: kon ting click lang maka ka donate ka na via paypal just click this link
# high: 74 yrs old lady trapped at 17 kap iligan st araneta subd qc all grilled windows locked water already at 2nd floor help rt
# low: rt folks please tweet calls for rescue in the san juan to cong. who has agreed to field them
# low: rt list evacuation centers relief operations in metro manila
# low: does anyone have list of evacuation centers of flood victims in metro manila &amp; provinces so we can sp readout
# low: rt ust hospitals generator already died please send some rescuers ---
# low: rt pagasa 4am advisory green warning for metro manila moderate heavy rains in next 3 hrs. threat of floods in low-lying ar ...
# low: concepcion integrated school in marikina has 582 families no food yet the whole day
# low: rt philippine floods kill more than 50 people parts of manila evacuated
# low: rt public service announcement gt pls rt for faster response help is on the way ...
# low: rt ust hospital food shortage
# low: rt mcdonalds restaurants open in metro manila are still accepting donations rice noodles bottled water etc for flood vic ...
# low: im kinda sad &amp; worried about ma nilas current flood its gotten worse in some areas
# high: help u erm hospital brownout &amp; icu patients on generator generators about to die flood almost at 3rd flr where the nursery is
# low: rt hi can every tweet with hashtag be a 1 donation to the philippines victims - pls re tweet this unt ...
# low: rt walked thru flood waters take one dose of doxycycline 20 0mg to guard against leptospirosis via
# low: ma nilas flood death toll rises too real i am sad prayers to the people
# low: ust hospitals generators already died
# low: rt rt ust hospitals generator already died please send some rescuers ...
# high: rt 78 michael raymond st marietta romeo vill sta lucia pasig city
# low: please rt. kindly course your donations through sts cholas t icas college manila hotline 567 7 686 to 89

# %%
for idx in right_cluster:
    print(f'{data[data_ids[idx]]["label"]}: {data[data_ids[idx]]["text"]}')
# Out:
# high: rt concepcion integrated school marikina has 582 families no food yet the whole day please rt
# low: break muna :-) read this open letter to h daw kasi after gener ps si helen yun not you
# low: pagasa 9pm advisory red warning for metro manila heavy intense rains in next 3 hrs. floods in low-lying areas near rivers
# high: rescue needed in romualdez st. cor kalen tong 1st house beside caltex lolo and lola residing
# low: rt sending love and worry to the philippines will also send aid donation using info
# low: rt mayor jun binay also says that will also receive calls for rescue in the makati area | via usec ...
# low: rt help needed in malabon people need drinking water ready-to-eat food &amp; meds
# low: rt want to donate or to volunteer check out this list via
# low: rt reported florentino bernardo and company antonette st parkway vill agd brgy apolonio samson 094 360 5 1153
# low: manila residents clean up after deadly floods
# low: rt please help me spread this i cant be online this week ...
# low: rt two important hash tags to take note of please make sure to use the correct one and rt ...
# high: rt rt feu science building help is needed there are 39 stranded students in there please send people the ...
# low: please rt needs donations and volunteers
# low: rt the flood victims of manila need soap pampers water and hot food please we are opening our malate branch ...
# low: help hab agat victims pls donate to red cross smart text red lt1 0255 0 or 100 gt to 4 143 globe text red lt 525 5010 0 or 300 gt to 2 899
# low: aug 11 shows tix for 3pm p200 tix for 8pm p500 all profits donated to contact 091 7500 2 462 for tickets
# low: text red lta m tgt to 2 899 donate even small amounts to red cross 205 0100 be generous with our
# low: rt for rescue needs tweet the details of the person &amp; exact place with the hashtag for relief efforts p ...
# low: rt i hope my fellow pino ys are safe esp the ones who are involved in the heavy rain flood and landslide in manila :( ...
# high: rt anyone from san mateo rizal who can rescue this person
# low: rt and for details about relief operations way to drop of donations and other ways to help
# high: rt de los santos medical on e. rod w/o food power needs help -
# high: rt family needs rescuing address 55 gui rayan st. brgy dona imelda araneta ave qc pls rt
# low: pagasa 9pm advisory red warning for metro manila heavy intense rains in next 3 hrs. floods in low-lying areas near rivers
# high: we need rescue here we need to evacuate address 212 m.h. del pilar st tinajero s malabon city please help them
# low: rt sabi nga nila work for a cause not for applause
# low: rt philippine capital hit by floods
# high: rt rt residents of villamor air base pasay city needs help
# low: rt rt pls rt for those who want to donate gt
# high: rt pls obando bulacan esp my family needs food and clean water flood chest deep inside our house pls send them
# low: rt advisory truck ban is lifted tomorrow friday august 10 for all trucks carrying food items
# high: rt family needs rescuing address 55 gui rayan st. brgy dona imelda araneta ave qc pls rt
# high: rt pa rescue po my kuya hs wife ampa mp kid w dogs stock cont
# high: rt pls rt bea bautista 6 people baby 1223 maria christina st sampaloc manila chest deep water + live wire ...
# low: rt keep tweeting us so we can share updates with our followers were updating this list too
# low: does tweeting the contact details w hashtag actually help is there a number i can text to report people in danger
# high: more medicines and plastic and boxes needed in uaa mpp please donate
# low: rt lgus schools extend class suspension until wednesday
# low: hashtags help coordinate relief efforts in philippine floods in the midst of widespread flooding in manila w
# low: rt im auctioning a cosplay for charity 100 of this listing goes to the philippine flood disaster relief so please ...
# low: philippine capital hit by floods
# high: rt rescue request a villa st brgy batis san juan city
# low: manila floods sweep away peace of mind for uae filipinos
# low: nst news appeal to help two million philippine flood victims manila philippine authorities appealed thursday ...
# high: rt pgh u erm and ust hospital are flooded supplies are running low patients and staff need food and water
# low: bn updated where to bring your donations or to volunteer
# low: rt mayor jun binay says to report calls for rescue in the makati area to 02 - 870 1000 | via
# low: rt urgent - help is needed in ust hospital flood has reached the buildings 2nd level
# low: rt rescue and coordinating operations like today is where twitter really stands out
